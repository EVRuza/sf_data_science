# %% [markdown]
# # ИГРА "УГАДАЙ ЧИСЛО"

# %%
from game_hw import score_game
from game_hw import random_predict

# %% [markdown]
# ## Компьютер угадывает число
#  - генерится случайное натуральное число
#  - компьютер угадывает число за _n_ попыток
#  - делается несколько подходов, по итогам определяется среднее количество попыток

# %%
score_game(random_predict)
# Out:
# Среднее количество попыток, за которое ваш алгоритм угадывает число: 8
# 8
